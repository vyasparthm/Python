# %% [markdown]
# ## Headfirst Python
# ### This will be a little overview kind of notebook with a few tricks from headfirst's python book.
# ##### 1. Simple lists

# %%
movies = ['Captain America: The First Avenger', 'Iron Man','ron Man 2','Thor']

# %%
print(movies)
# Out:
# ['Captain America: The First Avenger', 'Iron Man', 'ron Man 2', 'Thor']

# %%
#Lists are just like arrays and can be printed or manipulated by using an index.. Index starts from 0

print(movies[1])
# Out:
# Iron Man

# %% [markdown]
# Lets add more data to the list, Let's say the year movies originated

# %%
movies = ['Captain America: The First Avenger','1943', 'Iron Man','2010','Iron Man 2','2011','Thor','2011']

# %%
movies
# Out:
# ['Captain America: The First Avenger',
#  '1943',
#  'Iron Man',
#  '2010',
#  'Iron Man 2',
#  '2011',
#  'Thor',
#  '2011']

# %% [markdown]
# ### List Methods

# %%
#Length
print('Before pop: ',len(movies))
movies.pop() #Remove last
print('After Pop: ',len(movies))
movies.extend(['2011'])
print('After Extend: ',movies)
movies.insert(0,'Batman')
print('After Insert: ',movies)
movies.remove('Batman')
print('After Removal: ',movies)
# Out:
# Before pop:  8
# After Pop:  7
# After Extend:  ['Captain America: The First Avenger', '1943', 'Iron Man', '2010', 'Iron Man 2', '2011', 'Thor', '2011']
# After Insert:  ['Batman', 'Captain America: The First Avenger', '1943', 'Iron Man', '2010', 'Iron Man 2', '2011', 'Thor', '2011']
# After Removal:  ['Captain America: The First Avenger', '1943', 'Iron Man', '2010', 'Iron Man 2', '2011', 'Thor', '2011']

# %% [markdown]
# Python lists can contain data of mixed type. It’s perfectly OK
# to mix strings with numbers within the same Python list. In fact,
# you can mix more than just strings and numbers; you can store
# data of any type in a single list, if you like.
#
# Lets see how you can access the list.

# %%
print(movies[0]) # Just add the index number and Python will take care of it
# Out:
# Captain America: The First Avenger

# %%
# Lets try and iterate through the list and print everything witha for loop
# NOTE: Make sure your indentations are correct.
# As per HeadFirst labs, we can say that Lists are Array but "Arrays on Steroids!!"
for item in movies:
    print(item,'\n') # \n for new line
# Out:
# Captain America: The First Avenger
#
# 1943
#
# Iron Man
#
# 2010
#
# Iron Man 2
#
# 2011
#
# Thor
#
# 2011

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# You can also store a list within list

movies = ["The Holy Grail", 1975, "Terry Jones & Terry Gilliam", 91,["Graham Chapman",["Michael Palin", "John Cleese", "Terry Gilliam", "Eric Idle", "Terry Jones"]]]
print(movies[4][1][3])
# Out:
# Eric Idle

# %%
for item in movies:
    print(item)
# Out:
# The Holy Grail
# 1975
# Terry Jones & Terry Gilliam
# 91
# ['Graham Chapman', ['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle', 'Terry Jones']]

# %%
# Now lets try an put a condition

for each_item in movies:
    if isinstance(each_item,list):
        for nested_item in each_item:
            print(nested_item)
    else:
        print(each_item)
# Out:
# The Holy Grail
# 1975
# Terry Jones & Terry Gilliam
# 91
# Graham Chapman
# ['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle', 'Terry Jones']

# %%
# lets get a little better version of what we just did above

for each_item in movies:
    if isinstance(each_item,list):
        for nested_item in each_item:
            if isinstance(nested_item,list):
                for deep_item in nested_item:
                    print(deep_item)
            else:
                print(nested_item)
    else:
        print(each_item)
# Out:
# The Holy Grail
# 1975
# Terry Jones & Terry Gilliam
# 91
# Graham Chapman
# Michael Palin
# John Cleese
# Terry Gilliam
# Eric Idle
# Terry Jones

# %% [markdown]
# ## Don’t repeat code; create a function
# Take a look at the code that you’ve created so far, which (in an effort to save
# you from having your brain explode) has already been amended to process yet
# another nested list. Notice anything?
#
# ![image.png](attachment:image.png)

# %%
# How about we write a fuction rather than writing complex loops?
def nested_lists(the_list):
    for each_item in the_list:
        if isinstance(each_item,list):
            nested_lists(each_item)
        else:
            print(each_item)

# %%
nested_lists(movies)
# NOTE:  Python 3 defaults its recursion limit to 1,000
# Out:
# The Holy Grail
# 1975
# Terry Jones & Terry Gilliam
# 91
# Graham Chapman
# Michael Palin
# John Cleese
# Terry Gilliam
# Eric Idle
# Terry Jones
